# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
import seaborn as sns
from sklearn.preprocessing import RobustScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('f.csv')
df.head(3)
# Out:
#    area  Year  Rooms        Location  Floor         Price
# 0    87  1400      2       Marzdaran    7.0  1.392000e+10
# 1    98  1397      2  Kooy-e Ferdows    5.0  1.060000e+10
# 2    60  1396      1     Ebrahimabad    1.0  1.560000e+10

# %%
df = df.dropna()

# %%
x = df.drop(columns='Price')
y = df['Price']

# %%
df = df.drop(columns='Location')
df.corr()
# Out:
#            area      Year     Rooms     Floor     Price
# area   1.000000  0.181764  0.721469  0.208648  0.082619
# Year   0.181764  1.000000  0.179407  0.313806  0.050055
# Rooms  0.721469  0.179407  1.000000  0.223827  0.091703
# Floor  0.208648  0.313806  0.223827  1.000000  0.014926
# Price  0.082619  0.050055  0.091703  0.014926  1.000000

# %%
preprocessing = ColumnTransformer(transformers=[
    ('scaling', RobustScaler(), ['area', 'Year', 'Rooms', 'Floor']),
    ('encoder', OneHotEncoder(handle_unknown='ignore'), ['Location'])
])

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, train_size=0.8, random_state=42)

# %%
pipeline = Pipeline(steps=[
    ('pre', preprocessing),
    ('model', KNeighborsRegressor())
])

# %%
grid = GridSearchCV(estimator=pipeline,
                    param_grid={'model__n_neighbors' : [5, 21, 23, 25, 27],
                                'model__metric' : ['euclidean', 'manhattan']},
                    cv = 50,
                    verbose=1,
                    scoring='r2',
                    error_score='raise')

# %%
grid.fit(xtrain, ytrain)
# Out:
# Fitting 50 folds for each of 10 candidates, totalling 500 fits
# GridSearchCV(cv=50, error_score='raise',
#              estimator=Pipeline(steps=[('pre',
#                                         ColumnTransformer(transformers=[('scaling',
#                                                                          RobustScaler(),
#                                                                          ['area',
#                                                                           'Year',
#                                                                           'Rooms',
#                                                                           'Floor']),
#                                                                         ('encoder',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['Location'])])),
#                                        ('model', KNeighborsRegressor())]),
#              param_grid={'model__metric': ['euclidean', 'manhattan'],
#                          'model__n_neighbors': [5, 21, 23, 25, 27]},
#              scoring='r2', verbose=1)

# %%
model = grid.best_estimator_
model.fit(xtrain, ytrain)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('scaling', RobustScaler(),
#                                                   ['area', 'Year', 'Rooms',
#                                                    'Floor']),
#                                                  ('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Location'])])),
#                 ('model',
#                  KNeighborsRegressor(metric='euclidean', n_neighbors=27))])

# %%
ytrain_pred = model.predict(xtrain)
ytest_pred = model.predict(xtest)

# %%
r2_score(ytrain, ytrain_pred)
# Out:
# 0.02350239540116117

# %%
r2_score(ytest, ytest_pred)
# Out:
# -0.18448656365734295
